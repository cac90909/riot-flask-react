# %%
from riotwatcher import LolWatcher, ApiError
import pandas as pd
import collections
import matplotlib.pyplot as plt
import json

# %%
def create_watcher_obj(): #From the riotwater module, creates a wrapper watcher object that can access riot api
    api_key = get_api_key()
    watcher = LolWatcher(api_key)
    return watcher

# %%
def get_api_key(): #Called inside of "create_watcher_obj()" and simply reads the riot api key text file

    api_file = open("../riot_api_key.txt","r")
    api_key = api_file.read()
    api_file.close()
    return api_key

def get_acc_id(region='na1', summoner_name='we and i'): #Called inside of "get_match_list(x,y)"
     
    watcher_summoner = watcher.summoner.by_name(region,summoner_name)
    return watcher_summoner['accountId']

def get_match_list(region='na1', summoner_name="we and i"): #Returns an account's list of matches
    
    acc_id = get_acc_id(region, summoner_name)
    my_matches = watcher.match.matchlist_by_account(region, acc_id)
    return my_matches['matches']

def get_game_id_list(matchlist): #Given a matchlist, returns the game id of every match
    
    game_id_list = []
    for match in matchlist:
        game_id_list.append(match['gameId'])
    return game_id_list
        
def get_match_detail(game_id, region ='na1'): #Returns the summary details of a match
    
    match_detail = watcher.match.by_id(region, game_id)
    return match_detail

def get_match_timeline(game_id, region='na1'): #Returns a match's timeline object
    
    timeline = watcher.match.timeline_by_match(region, game_id)
    return timeline['frames'] #The other key in the timeline object is 'frameInterval' which I deemed unimportant

# %%
def jsonify_info(info):
    
    json_object = json.dumps(info, indent = 4)
    return json_object

# %%
def package_events_info():
    pass
def package_timeline_info():
    pass
def package_summary_info():
    pass

# %%
def package_game_data_struc(game_id, region):

    watcher = create_watcher_obj()

# %%
watcher = create_watcher_obj()

# %%
match_list = get_match_list()
game_id_list = get_game_id_list(match_list)
game_id_example = game_id_list[0]

time = get_match_timeline(game_id_example)
print(time)
# Out:
# [{'participantFrames': {'1': {'participantId': 1, 'position': {'x': 554, 'y': 581}, 'currentGold': 500, 'totalGold': 500, 'level': 1, 'xp': 0, 'minionsKilled': 0, 'jungleMinionsKilled': 0, 'dominionScore': 0, 'teamScore': 0}, '2': {'participantId': 2, 'position': {'x': 557, 'y': 345}, 'currentGold': 500, 'totalGold': 500, 'level': 1, 'xp': 0, 'minionsKilled': 0, 'jungleMinionsKilled': 0, 'dominionScore': 0, 'teamScore': 0}, '3': {'participantId': 3, 'position': {'x': 335, 'y': 269}, 'currentGold': 500, 'totalGold': 500, 'level': 1, 'xp': 0, 'minionsKilled': 0, 'jungleMinionsKilled': 0, 'dominionScore': 0, 'teamScore': 0}, '4': {'participantId': 4, 'position': {'x': 194, 'y': 457}, 'currentGold': 500, 'totalGold': 500, 'level': 1, 'xp': 0, 'minionsKilled': 0, 'jungleMinionsKilled': 0, 'dominionScore': 0, 'teamScore': 0}, '5': {'participantId': 5, 'position': {'x': 329, 'y': 650}, 'currentGold': 500, 'totalGold': 500, 'level': 1, 'xp': 0, 'minionsKilled': 0, 'jungleMinionsKilled': 0, 'dominionScore': 0, 'teamScore': 0}, '6': {'participantId': 6, 'position': {'x': 14180, 'y': 14271}, 'currentGold': 500, 'totalGold': 500, 'level': 1, 'xp': 0, 'minionsKilled': 0, 'jungleMinionsKilled': 0, 'dominionScore': 0, 'teamScore': 0}, '7': {'participantId': 7, 'position': {'x': 14176, 'y': 14506}, 'currentGold': 500, 'totalGold': 500, 'level': 1, 'xp': 0, 'minionsKilled': 0, 'jungleMinionsKilled': 0, 'dominionScore': 0, 'teamScore': 0}, '8': {'participantId': 8, 'position': {'x': 14398, 'y': 14582}, 'currentGold': 500, 'totalGold': 500, 'level': 1, 'xp': 0, 'minionsKilled': 0, 'jungleMinionsKilled': 0, 'dominionScore': 0, 'teamScore': 0}, '9': {'participantId': 9, 'position': {'x': 14539, 'y': 14394}, 'currentGold': 500, 'totalGold': 500, 'level': 1, 'xp': 0, 'minionsKilled': 0, 'jungleMinionsKilled': 0, 'dominionScore': 0, 'teamScore': 0}, '10': {'participantId': 10, 'position': {'x': 14404, 'y': 14201}, 'currentGold': 500, 'totalGold': 500, 'level': 1, 'xp': 0, 'minionsKilled': 0, 'jungleMinionsKilled': 0, 'dominionScore': 0, 'teamScore': 0}}, 'events': [], 'timestamp': 0}, {'participantFrames': {'1': {'participantId': 1, 'position': {'x': 6308, 'y': 4436}, 'currentGold': 0, 'totalGold': 500, 'level': 1, 'xp': 0, 'minionsKilled': 0, 'jungleMinionsKilled': 0, 'dominionScore': 0, 'teamScore': 0}, '2': {'participantId': 2, 'position': {'x': 1632, 'y': 10148}, 'currentGold': 0, 'totalGold': 500, 'level': 1, 'xp': 0, 'minionsKilled': 0, 'jungleMinionsKilled': 0, 'dominionScore': 0, 'teamScore': 0}, '3': {'participantId': 3, 'position': {'x': 7922, 'y': 5140}, 'currentGold': 0, 'totalGold': 500, 'level': 1, 'xp': 0, 'minionsKilled': 0, 'jungleMinionsKilled': 0, 'dominionScore': 0, 'teamScore': 0}, '4': {'participantId': 4, 'position': {'x': 8984, 'y': 4069}, 'currentGold': 0, 'totalGold': 500, 'level': 1, 'xp': 0, 'minionsKilled': 0, 'jungleMinionsKilled': 0, 'dominionScore': 0, 'teamScore': 0}, '5': {'participantId': 5, 'position': {'x': 8924, 'y': 4363}, 'currentGold': 40, 'totalGold': 540, 'level': 1, 'xp': 0, 'minionsKilled': 0, 'jungleMinionsKilled': 0, 'dominionScore': 0, 'teamScore': 0}, '6': {'participantId': 6, 'position': {'x': 8586, 'y': 5476}, 'currentGold': 100, 'totalGold': 500, 'level': 1, 'xp': 0, 'minionsKilled': 0, 'jungleMinionsKilled': 0, 'dominionScore': 0, 'teamScore': 0}, '7': {'participantId': 7, 'position': {'x': 8695, 'y': 5913}, 'currentGold': 0, 'totalGold': 500, 'level': 1, 'xp': 0, 'minionsKilled': 0, 'jungleMinionsKilled': 0, 'dominionScore': 0, 'teamScore': 0}, '8': {'participantId': 8, 'position': {'x': 8549, 'y': 5519}, 'currentGold': 0, 'totalGold': 500, 'level': 1, 'xp': 0, 'minionsKilled': 0, 'jungleMinionsKilled': 0, 'dominionScore': 0, 'teamScore': 0}, '9': {'participantId': 9, 'position': {'x': 6649, 'y': 11371}, 'currentGold': 0, 'totalGold': 500, 'level': 1, 'xp': 0, 'minionsKilled': 0, 'jungleMinionsKilled': 0, 'dominionScore': 0, 'teamScore': 0}, '10': {'participantId': 10, 'position': {'x': 9271, 'y': ...

# %%
#def get_relev_event_info(timeline): next function to define

def get_relev_timeline_info(timeline):
    
    a_dict = collections.defaultdict(list)
    
    for frame in timeline:
        temp_list = []
        for participant in frame['participantFrames']:
            relev_keys = ['participantId', 'position', 'currentGold', 
                          'totalGold', 'level', 'xp', 'minionsKilled', 'jungleMinionsKilled']
            
            temp_dict = {x: frame['participantFrames'][participant][x] for x in relev_keys if x in frame['participantFrames'][participant]}
            packaged_temp_dict = {participant:temp_dict}
            temp_list.append(packaged_temp_dict)
        a_dict[frame['timestamp']] = temp_list    
        
    return a_dict

# %%
def get_relev_event_info(timeline):
    
    pass

# %%
data_struc = get_relev_timeline_info(time)
data_struc_json = jsonify_info(data_struc)
print(data_struc_json)
# Out:
# {
#     "0": [
#         {
#             "1": {
#                 "participantId": 1,
#                 "position": {
#                     "x": 554,
#                     "y": 581
#                 },
#                 "currentGold": 500,
#                 "totalGold": 500,
#                 "level": 1,
#                 "xp": 0,
#                 "minionsKilled": 0,
#                 "jungleMinionsKilled": 0
#             }
#         },
#         {
#             "2": {
#                 "participantId": 2,
#                 "position": {
#                     "x": 557,
#                     "y": 345
#                 },
#                 "currentGold": 500,
#                 "totalGold": 500,
#                 "level": 1,
#                 "xp": 0,
#                 "minionsKilled": 0,
#                 "jungleMinionsKilled": 0
#             }
#         },
#         {
#             "3": {
#                 "participantId": 3,
#                 "position": {
#                     "x": 335,
#                     "y": 269
#                 },
#                 "currentGold": 500,
#                 "totalGold": 500,
#                 "level": 1,
#                 "xp": 0,
#                 "minionsKilled": 0,
#                 "jungleMinionsKilled": 0
#             }
#         },
#         {
#             "4": {
#                 "participantId": 4,
#                 "position": {
#                     "x": 194,
#                     "y": 457
#                 },
#                 "currentGold": 500,
#                 "totalGold": 500,
#                 "level": 1,
#                 "xp": 0,
#                 "minionsKilled": 0,
#                 "jungleMinionsKilled": 0
#             }
#         },
#         {
#             "5": {
#                 "participantId": 5,
#                 "position": {
#                     "x": 329,
#                     "y": 650
#                 },
#                 "currentGold": 500,
#                 "totalGold": 500,
#                 "level": 1,
#                 "xp": 0,
#                 "minionsKilled": 0,
#                 "jungleMinionsKilled": 0
#             }
#         },
#         {
#             "6": {
#                 "participantId": 6,
#                 "position": {
#                     "x": 14180,
#                     "y": 14271
#                 },
#                 "currentGold": 500,
#                 "totalGold": 500,
#                 "level": 1,
#                 "xp": 0,
#                 "minionsKilled": 0,
#                 "jungleMinionsKilled": 0
#             }
#         },
#         {
#             "7": {
#                 "participantId": 7,
#                 "position": {
#                     "x": 14176,
#                     "y": 14506
#                 },
#                 "currentGold": 500,
#                 "totalGold": 500,
#                 "level": 1,
#                 "xp": 0,
#                 "minionsKilled": 0,
#                 "jungleMinionsKilled": 0
#             }
#         },
#         {
#             "8": {
#                 "participantId": 8,
#                 "position": {
#                     "x": 14398,
#                     "y": 14582
#                 },
#                 "currentGold": 500,
#                 "totalGold": 500,
#                 "level": 1,
#                 "xp": 0,
#                 "minionsKilled": 0,
#                 "jungleMinionsKilled": 0
#             }
#         },
#         {
#             "9": {
#                 "participantId": 9,
#                 "position": {
#                     "x": 14539,
#                     "y": 14394
#                 },
#                 "currentGold": 500,
#                 "totalGold": 500,
#                 "level": 1,
#                 "xp": 0,
#                 "minionsKilled": 0,
#                 "jungleMinionsKilled": 0
#             }
#         },
#         {
#             "10": {
#                 "participantId": 10,
#                 "position": {
#                     "x": 14404,
#                     "y": 14201
#                 },
#                 "currentGold": 500,
#                 "totalGold": 500,
#                 "level": 1,
#                 "xp": 0,
#                 "minionsKilled": 0,
#                 "jungleMinionsKilled": 0
#             }
#         }
#     ],
#     "60019": [
#         {
#             "1": {
#                 "participantId": 1,
#                 "position": {
#                     "x": 6308,
#                     "y": 4436
#                 },
#                 "currentGold": 0,
#                 "totalGold": 500,
#                 "level": 1,
#                 "xp": 0,
#                 "minionsKilled": 0,
#                 "jungleMinionsKilled": 0
#             }
#         },
#         {
#             "2": {
#                 "participantId": 2,
#                 "position": {
#                     "x": 1632,
#                     "y": 10148
#                 },
#                 "currentGold": 0,
#                 "totalGold": 500,
#                 "level": 1,
#                 "xp": 0,
#                 "minionsKilled": 0,
#                 "jungleMinionsKilled": 0
#             }
#         },
#         {
#             "3": {
#                 "participantId": 3,
#                 "position": {
#                     "x": 7922,
#                     "y": 5140
#                 },
#                 "currentGold": 0,
#                 "totalGold": 500,
#                 "level": 1,
#                 "xp": 0,
#                 "minionsKilled": 0,
#                 "jungleMinionsKilled": 0
#             }
#         },
#         {
#             "4": {
#                 "participantId": 4,
#                 "position": {
#                     "x": 8984,
#                     "y": 4069
#                 },
#                 "currentGold": 0,
#                 "totalGold": 500,
#                 "level": 1,
#                 "xp": 0,
#                 "minionsKilled": 0,
#                 "jungleMinionsKilled": 0
#             }
#         },
#         {
#             "5": {
#                 "participantId": 5,
#                 "position": {
#                     "x": 8924,
#                     "y": 4363
#                 },
#                 "currentGold": 40,
#                 "totalGold": 540,
#                 "level": 1,
#                 "xp": 0,
#                 "minionsKilled": 0,
#                 "jungleMinionsKilled": 0
#             }
#         },
#         {
#             "6": {
#                 "participantId": 6,
#                 "position": {
#                     "x": 8586,
#                     "y": 5476
#                 },
#                 "currentGold": 100,
#                 "totalGold": 500,
#                 "level": 1,
#                 "xp": 0,
#                 "minionsKilled": 0,
#                 "jungleMinionsKilled": 0
#             }
#         },
#         {
#             "7": {
#                 "participantId": 7,
#                 "position": {
#                     "x": 8695,
#                     "y": 5913
#                 },
#                 "currentGold": 0,
#                 "totalGold": 500,
#                 "level": 1,
#                 "xp": 0,
#                 "minionsKilled": 0,
#                 "jungleMinionsKilled": 0
#             }
#         },
#         {
#             "8": {
#                 "participantId": 8,
#                 "position": {
#                     "x": 8549,
#                     "y": 5519
#                 },
#                 "currentGold": 0,
#                 "totalGold": 500,
#                 "level": 1,
#                 "xp": 0,
#                 "minionsKilled": 0,
#                 "jungleMinionsKilled": 0
#             }
#         },
#         {
#             "9": {
#                 "participantId": 9,
#                 "position": {
#                     "x": 6649,
#                     "y": 11371
#                 },
#                 "currentGold": 0,
#                 "totalGold": 500,
#                 "level": 1,
#                 "xp": 0,
#                 "minionsKilled": 0,
#                 "jungleMinionsKilled": 0
#             }
#         },
#         {
#             "10": {
#                 "participantId": 10,
#                 "position": {
#                     "x": 9271,
#                     "y": 5575
#                 },
#                 "currentGold": 0,
#                 "totalGold": 500,
#                 "level": 1,
#                 "xp": 0,
#                 "minionsKilled": 0,
#                 "jungleMinionsKilled": 0
#             }
#         }
#     ],
#     "120031": [
#         {
#             "1": {
#                 "participantId": 1,
#                 "position": {
#                     "x": 6971,
#                     "y": 5269
#                 },
#                 "currentGold": 128,
#                 "totalGold": 628,
#                 "level": 2,
#                 "xp": 330,
#                 "minionsKilled": 0,
#                 "jungleMinionsKilled": 4
#             }
#         },
#         {
#             "2": {
#                 "participantId": 2,
#                 "position": {
#                     "x": 2488,
#                     "y": 12565
#                 },
#                 "currentGold": 20,
#                 "totalGold": 520,
#                 "level": 1,
#                 "xp": 211,
#                 "minionsKilled": 0,
#                 "jungleMinionsKilled": 0
#             }
#         },
#         {
#             "3": {
#                 "participantId": 3,
#                 "position": {
#                     "x": 6729,
#                     "y": 7064
#                 },
#                 "currentGold": 104,
#                 "totalGold": 604,
#                 "level": 1,
#                 "xp": 270,
#                 "minionsKilled": 5,
#                 "jungleMinionsKilled": 0
#             }
#         },
#         {
#             "4": {
#                 "participantId": 4,
#                 "position": {
#                     "x": 10912,
#                     "y": 2220
#                 },
#                 "currentGold": 20,
#                 "totalGold": 520,
#                 "level": 1,
#                 "xp": 0,
#                 "minionsKilled": 0,
#                 "jungleMinionsKilled": 0
#             }
#         },
#         {
#             "5": {
#                 "participantId": 5,
#                 "position": {
#                     "x": 10811,
#                     "y": 3452
#                 },
#                 "currentGold": 122,
#                 "totalGold": 622,
#                 "level": 1,
#                 "xp": 0,
#                 "minionsKilled": 0,
#                 "jungleMinionsKilled": 0
#             }
#         },
#         {
#             "6": {
#                 "participantId": 6,
#                 "position": {
#                     "x": 10136,
#                     "y": 9003
#                 },
#                 "currentGold": 220,
#                 "totalGold": 620,
#                 "level": 2,
#                 "xp": 320,
#                 "minionsKilled": 0,
#                 "jungleMinionsKilled": 4
#             }
#         },
#         {
#             "7": {
#                 "participantId": 7,
#                 "position": {
#                     "x": 7784,
#                     "y": 7289
#                 },
#                 "currentGold": 41,
#                 "totalGold": 541,
#                 "level": 1,
#                 "xp": 181,
#                 "minionsKilled": 1,
#                 "jungleMinionsKilled": 0
#             }
#         },
#         {
#             "8": {
#                 "participantId": 8,
#                 "position": {
#                     "x": 13049,
#                     "y": 3834
#                 },
#                 "currentGold": 20,
#                 "totalGold": 520,
#                 "level": 1,
#                 "xp": 0,
#                 "minionsKilled": 0,
#                 "jungleMinionsKilled": 0
#             }
#         },
#         {
#             "9": {
#                 "participantId": 9,
#                 "position": {
#                     "x": 2822,
#                     "y": 13085
#                 },
#                 "currentGold": 41,
#                 "totalGold": 541,
#                 "level": 1,
#                 "xp": 120,
#                 "minionsKilled": 1,
#                 "jungleMinionsKilled": 0
#             }
#         },
#         {
#             "10": {
#                 "participantId": 10,
#                 "position": {
#                     "x": 12415,
#                     "y": 5043
#                 },
#                 "currentGold": 22,
#                 "totalGold": 522,
#                 "level": 1,
#                 "xp": 0,
#                 "minionsKilled": 0,
#                 "jungleMinionsKilled": 0
#             }
#         }
#     ],
#     "180036": [
#         {
#             "1": {
#                 "participantId": 1,
#                 "position": {
#                     "x": 3361,
#                     "y": 8526
#                 },
#                 "currentGold": 328,
#                 "totalGold": 828,
#                 "level": 2,
#                 "xp": 502,
#                 "minionsKilled": 0,
#                 "jungleMinionsKilled": 8
#             }
#         },
#         {
#             "2": {
#                 "participantId": 2,
#                 "position": {
#                     "x": 2968,
#                     "y": 13025
#                 },
#                 "currentGold": 220,
#                 "totalGold": 720,
#                 "level": 3,
#                 "xp": 845,
#                 "minionsKilled": 4,
#                 "jungleMinionsKilled": 0
#             }
#         },
#         {
#             "3": {
#                 "participantId": 3,
#                 "position": {
#                     "x": 7318,
#                     "y": 7322
#                 },
#                 "currentGold": 424,
#                 "totalGold": 934,
#                 "level": 3,
#                 "xp": 882,
#                 "minionsKilled": 14,
#                 "jungleMinionsKilled": 0
#             }
#         },
#         {
#             "4": {
#                 "participantId": 4,
#                 "position": {
#                     "x": 13066,
#                     "y": 2909
#                 },
#                 "currentGold": 241,
#                 "totalGold": 741,
#                 "level": 2,
#                 "xp": 367,
#                 "minionsKilled": 6,
#                 "jungleMinionsKilled": 0
#             }
#         },
#         {
#             "5": {
#                 "participantId": 5,
#                 "position": {
#                     "x": 12957,
#                     "y": 2325
#                 },
#                 "currentGold": 337,
#                 "totalGold": 837,
#                 "level": 2,
#                 "xp": 337,
#                 "minionsKilled": 0,
#                 "jungleMinionsKilled": 0
#             }
#         },
#         {
#             "6": {
#                 "participantId": 6,
#                 "position": {
#                     "x": 3645,
#                     "y": 9715
#                 },
#                 "currentGold": 443,
#                 "totalGold": 843,
#                 "level": 2,
#                 "xp": 490,
#                 "minionsKilled": 0,
#                 "jungleMinionsKilled": 8
#             }
#         },
#         {
#             "7": {
#                 "participantId": 7,
#                 "position": {
#                     "x": 9715,
#                     "y": 9547
#                 },
#                 "currentGold": 199,
#                 "totalGold": 699,
#                 "level": 2,
#                 "xp": 422,
#                 "minionsKilled": 3,
#                 "jungleMinionsKilled": 0
#             }
#         },
#         {
#             "8": {
#                 "participantId": 8,
#                 "position": {
#                     "x": 13751,
#                     "y": 3514
#                 },
#                 "currentGold": 255,
#                 "totalGold": 755,
#                 "level": 2,
#                 "xp": 357,
#                 "minionsKilled": 7,
#                 "jungleMinionsKilled": 0
#             }
#         },
#         {
#             "9": {
#                 "participantId": 9,
#                 "position": {
#                     "x": 3700,
#                     "y": 13274
#                 },
#                 "currentGold": 241,
#                 "totalGold": 741,
#                 "level": 2,
#                 "xp": 601,
#                 "minionsKilled": 5,
#                 "jungleMinionsKilled": 0
#             }
#         },
#         {
#             "10": {
#                 "participantId": 10,
#                 "position": {
#                     "x": 13190,
#                     "y": 3881
#                 },
#                 "currentGold": 206,
#                 "totalGold": 706,
#                 "level": 2,
#                 "xp": 357,
#                 "minionsKilled": 3,
#                 "jungleMinionsKilled": 0
#             }
#         }
#     ],
#     "240058": [
#         {
#             "1": {
#                 "participantId": 1,
#                 "position": {
#                     "x": 5130,
#                     "y": 9514
#                 },
#                 "currentGold": 1028,
#                 "totalGold": 1528,
#                 "level": 3,
#                 "xp": 883,
#                 "minionsKilled": 0,
#                 "jungleMinionsKilled": 16
#             }
#         },
#         {
#             "2": {
#                 "participantId": 2,
#                 "position": {
#                     "x": 2992,
#                     "y": 12951
#                 },
#                 "currentGold": 364,
#                 "totalGold": 864,
#                 "level": 4,
#                 "xp": 1317,
#                 "minionsKilled": 5,
#                 "jungleMinionsKilled": 0
#             }
#         },
#         {
#             "3": {
#                 "participantId": 3,
#                 "position": {
#                     "x": 6872,
#                     "y": 6756
#                 },
#                 "currentGold": 824,
#                 "totalGold": 1334,
#                 "level": 4,
#                 "xp": 1264,
#                 "minionsKilled": 19,
#                 "jungleMinionsKilled": 0
#             }
#         },
#         {
#             "4": {
#                 "participantId": 4,
#                 "position": {
#                     "x": 13435,
#                     "y": 3992
#                 },
#                 "currentGold": 958,
#                 "totalGold": 1458,
#                 "level": 3,
#                 "xp": 875,
#                 "minionsKilled": 12,
#                 "jungleMinionsKilled": 0
#             }
#         },
#         {
#             "5": {
#                 "participantId": 5,
#                 "position": {
#                     "x": 13614,
#                     "y": 3897
#                 },
#                 "currentGold": 1063,
#                 "totalGold": 1563,
#                 "level": 3,
#                 "xp": 846,
#                 "minionsKilled": 1,
#                 "jungleMinionsKilled": 0
#             }
#         },
#         {
#             "6": {
#                 "participantId": 6,
#                 "position": {
#                     "x": 9591,
#                     "y": 5347
#                 },
#                 "currentGold": 116,
#                 "totalGold": 966,
#                 "level": 2,
#                 "xp": 490,
#                 "minionsKilled": 0,
#                 "jungleMinionsKilled": 8
#             }
#         },
#         {
#             "7": {
#                 "participantId": 7,
#                 "position": {
#                     "x": 7893,
#                     "y": 7565
#                 },
#                 "currentGold": 455,
#                 "totalGold": 955,
#                 "level": 3,
#                 "xp": 874,
#                 "minionsKilled": 10,
#                 "jungleMinionsKilled": 0
#             }
#         },
#         {
#             "8": {
#                 "participantId": 8,
#                 "position": {
#                     "x": 14063,
#                     "y": 7448
#                 },
#                 "currentGold": 63,
#                 "totalGold": 913,
#                 "level": 2,
#                 "xp": 451,
#                 "minionsKilled": 9,
#                 "jungleMinionsKilled": 0
#             }
#         },
#         {
#             "9": {
#                 "participantId": 9,
#                 "position": {
#                     "x": 3620,
#                     "y": 13705
#                 },
#                 "currentGold": 592,
#                 "totalGold": 1092,
#                 "level": 4,
#                 "xp": 1356,
#                 "minionsKilled": 16,
#                 "jungleMinionsKilled": 0
#             }
#         },
#         {
#             "10": {
#                 "participantId": 10,
#                 "position": {
#                     "x": 13801,
#                     "y": 7860
#                 },
#                 "currentGold": 205,
#                 "totalGold": 855,
#                 "level": 2,
#                 "xp": 451,
#                 "minionsKilled": 4,
#                 "jungleMinionsKilled": 0
#             }
#         }
#     ],
#     "300068": [
#         {
#             "1": {
#                 "participantId": 1,
#                 "position": {
#                     "x": 5734,
#                     "y": 5341
#                 },
#                 "currentGold": 1672,
#                 "totalGold": 2172,
#                 "level": 4,
#                 "xp": 1342,
#                 "minionsKilled": 0,
#                 "jungleMinionsKilled": 20
#             }
#         },
#         {
#             "2": {
#                 "participantId": 2,
#                 "position": {
#                     "x": 2473,
#                     "y": 12615
#                 },
#                 "currentGold": 584,
#                 "totalGold": 1084,
#                 "level": 5,
#                 "xp": 1951,
#                 "minionsKilled": 10,
#                 "jungleMinionsKilled": 0
#             }
#         },
#         {
#             "3": {
#                 "participantId": 3,
#                 "position": {
#                     "x": 5944,
#                     "y": 6138
#                 },
#                 "currentGold": 1452,
#                 "totalGold": 1972,
#                 "level": 4,
#                 "xp": 1679,
#                 "minionsKilled": 22,
#                 "jungleMinionsKilled": 0
#             }
#         },
#         {
#             "4": {
#                 "participantId": 4,
#                 "position": {
#                     "x": 12799,
#                     "y": 3293
#                 },
#                 "currentGold": 1251,
#                 "totalGold": 1751,
#                 "level": 4,
#                 "xp": 1197,
#                 "minionsKilled": 17,
#                 "jungleMinionsKilled": 0
#             }
#         },
#         {
#             "5": {
#                 "participantId": 5,
#                 "position": {
#                     "x": 13160,
#                     "y": 2811
#                 },
#                 "currentGold": 1318,
#                 "totalGold": 1818,
#                 "level": 4,
#                 "xp": 1167,
#                 "minionsKilled": 2,
#                 "jungleMinionsKilled": 0
#             }
#         },
#         {
#             "6": {
#                 "participantId": 6,
#                 "position": {
#                     "x": 10625,
#                     "y": 10055
#                 },
#                 "currentGold": 315,
#                 "totalGold": 1165,
#                 "level": 3,
#                 "xp": 776,
#                 "minionsKilled": 0,
#                 "jungleMinionsKilled": 12
#             }
#         },
#         {
#             "7": {
#                 "participantId": 7,
#                 "position": {
#                     "x": 8301,
#                     "y": 8353
#                 },
#                 "currentGold": 672,
#                 "totalGold": 1182,
#                 "level": 4,
#                 "xp": 1327,
#                 "minionsKilled": 14,
#                 "jungleMinionsKilled": 0
#             }
#         },
#         {
#             "8": {
#                 "participantId": 8,
#                 "position": {
#                     "x": 14039,
#                     "y": 4109
#                 },
#                 "currentGold": 381,
#                 "totalGold": 1231,
#                 "level": 3,
#                 "xp": 858,
#                 "minionsKilled": 17,
#                 "jungleMinionsKilled": 0
#             }
#         },
#         {
#             "9": {
#                 "participantId": 9,
#                 "position": {
#                     "x": 3054,
#                     "y": 13384
#                 },
#                 "currentGold": 903,
#                 "totalGold": 1403,
#                 "level": 5,
#                 "xp": 1930,
#                 "minionsKilled": 24,
#                 "jungleMinionsKilled": 0
#             }
#         },
#         {
#             "10": {
#                 "participantId": 10,
#                 "position": {
#                     "x": 13524,
#                     "y": 4123
#                 },
#                 "currentGold": 374,
#                 "totalGold": 1024,
#                 "level": 3,
#                 "xp": 828,
#                 "minionsKilled": 6,
#                 "jungleMinionsKilled": 0
#             }
#         }
#     ],
#     "360101": [
#         {
#             "1": {
#                 "participantId": 1,
#                 "position": {
#                     "x": 846,
#                     "y": 756
#                 },
#                 "currentGold": 990,
#                 "totalGold": 2480,
#                 "level": 4,
#                 "xp": 1692,
#                 "minionsKilled": 0,
#                 "jungleMinionsKilled": 28
#             }
#         },
#         {
#             "2": {
#                 "participantId": 2,
#                 "position": {
#                     "x": 1440,
#                     "y": 11266
#                 },
#                 "currentGold": 777,
#                 "totalGold": 1277,
#                 "level": 6,
#                 "xp": 2522,
#                 "minionsKilled": 14,
#                 "jungleMinionsKilled": 0
#             }
#         },
#         {
#             "3": {
#                 "participantId": 3,
#                 "position": {
#                     "x": 4475,
#                     "y": 4835
#                 },
#                 "currentGold": 37,
#                 "totalGold": 2157,
#                 "level": 5,
#                 "xp": 2010,
#                 "minionsKilled": 26,
#                 "jungleMinionsKilled": 0
#             }
#         },
#         {
#             "4": {
#                 "participantId": 4,
#                 "position": {
#                     "x": 5396,
#                     "y": 754
#                 },
#                 "currentGold": 74,
#                 "totalGold": 1874,
#                 "level": 4,
#                 "xp": 1347,
#                 "minionsKilled": 17,
#                 "jungleMinionsKilled": 0
#             }
#         },
#         {
#             "5": {
#                 "participantId": 5,
#                 "position": {
#                     "x": 3814,
#                     "y": 752
#                 },
#                 "currentGold": 67,
#                 "totalGold": 1992,
#                 "level": 4,
#                 "xp": 1317,
#                 "minionsKilled": 2,
#                 "jungleMinionsKilled": 0
#             }
#         },
#         {
#             "6": {
#                 "participantId": 6,
#                 "position": {
#                     "x": 1849,
#                     "y": 11497
#                 },
#                 "currentGold": 533,
#                 "totalGold": 1383,
#                 "level": 3,
#                 "xp": 1106,
#                 "minionsKilled": 0,
#                 "jungleMinionsKilled": 16
#             }
#         },
#         {
#             "7": {
#                 "participantId": 7,
#                 "position": {
#                     "x": 7079,
#                     "y": 6926
#                 },
#                 "currentGold": 984,
#                 "totalGold": 1494,
#                 "level": 5,
#                 "xp": 1976,
#                 "minionsKilled": 25,
#                 "jungleMinionsKilled": 0
#             }
#         },
#         {
#             "8": {
#                 "participantId": 8,
#                 "position": {
#                     "x": 13233,
#                     "y": 2511
#                 },
#                 "currentGold": 714,
#                 "totalGold": 1564,
#                 "level": 4,
#                 "xp": 1251,
#                 "minionsKilled": 30,
#                 "jungleMinionsKilled": 0
#             }
#         },
#         {
#             "9": {
#                 "participantId": 9,
#                 "position": {
#                     "x": 2506,
#                     "y": 12288
#                 },
#                 "currentGold": 1180,
#                 "totalGold": 1680,
#                 "level": 6,
#                 "xp": 2411,
#                 "minionsKilled": 33,
#                 "jungleMinionsKilled": 0
#             }
#         },
#         {
#             "10": {
#                 "participantId": 10,
#                 "position": {
#                     "x": 12513,
#                     "y": 2787
#                 },
#                 "currentGold": 551,
#                 "totalGold": 1201,
#                 "level": 4,
#                 "xp": 1221,
#                 "minionsKilled": 9,
#                 "jungleMinionsKilled": 0
#             }
#         }
#     ],
#     "420109": [
#         {
#             "1": {
#                 "participantId": 1,
#                 "position": {
#                     "x": 9986,
#                     "y": 4465
#                 },
#                 "currentGold": 172,
#                 "totalGold": 2662,
#                 "level": 5,
#                 "xp": 1813,
#                 "minionsKilled": 1,
#                 "jungleMinionsKilled": 28
#             }
#         },
#         {
#             "2": {
#                 "participantId": 2,
#                 "position": {
#                     "x": 3285,
#                     "y": 13057
#                 },
#                 "currentGold": 997,
#                 "totalGold": 1497,
#                 "level": 6,
#                 "xp": 3003,
#                 "minionsKilled": 20,
#                 "jungleMinionsKilled": 0
#             }
#         },
#         {
#             "3": {
#                 "participantId": 3,
#                 "position": {
#                     "x": 10569,
#                     "y": 4652
#                 },
#                 "currentGold": 497,
#                 "totalGold": 2617,
#                 "level": 6,
#                 "xp": 2464,
#                 "minionsKilled": 30,
#                 "jungleMinionsKilled": 0
#             }
#         },
#         {
#             "4": {
#                 "participantId": 4,
#                 "position": {
#                     "x": 13411,
#                     "y": 4007
#                 },
#                 "currentGold": 434,
#                 "totalGold": 2234,
#                 "level": 5,
#                 "xp": 1791,
#                 "minionsKilled": 25,
#                 "jungleMinionsKilled": 0
#             }
#         },
#         {
#             "5": {
#                 "participantId": 5,
#                 "position": {
#                     "x": 13663,
#                     "y": 3812
#                 },
#                 "currentGold": 335,
#                 "totalGold": 2260,
#                 "level": 4,
#                 "xp": 1671,
#                 "minionsKilled": 4,
#                 "jungleMinionsKilled": 0
#             }
#         },
#         {
#             "6": {
#                 "participantId": 6,
#                 "position": {
#                     "x": 7693,
#                     "y": 9742
#                 },
#                 "currentGold": 695,
#                 "totalGold": 1545,
#                 "level": 4,
#                 "xp": 1252,
#                 "minionsKilled": 0,
#                 "jungleMinionsKilled": 18
#             }
#         },
#         {
#             "7": {
#                 "participantId": 7,
#                 "position": {
#                     "x": 13976,
#                     "y": 13708
#                 },
#                 "currentGold": 378,
#                 "totalGold": 1763,
#                 "level": 6,
#                 "xp": 2427,
#                 "minionsKilled": 33,
#                 "jungleMinionsKilled": 0
#             }
#         },
#         {
#             "8": {
#                 "participantId": 8,
#                 "position": {
#                     "x": 14122,
#                     "y": 4571
#                 },
#                 "currentGold": 937,
#                 "totalGold": 1787,
#                 "level": 4,
#                 "xp": 1682,
#                 "minionsKilled": 33,
#                 "jungleMinionsKilled": 0
#             }
#         },
#         {
#             "9": {
#                 "participantId": 9,
#                 "position": {
#                     "x": 3977,
#                     "y": 13542
#                 },
#                 "currentGold": 1578,
#                 "totalGold": 2078,
#                 "level": 6,
#                 "xp": 2987,
#                 "minionsKilled": 46,
#                 "jungleMinionsKilled": 0
#             }
#         },
#         {
#             "10": {
#                 "participantId": 10,
#                 "position": {
#                     "x": 14292,
#                     "y": 13712
#                 },
#                 "currentGold": 685,
#                 "totalGold": 1335,
#                 "level": 4,
#                 "xp": 1410,
#                 "minionsKilled": 9,
#                 "jungleMinionsKilled": 0
#             }
#         }
#     ],
#     "480132": [
#         {
#             "1": {
#                 "participantId": 1,
#                 "position": {
#                     "x": 8323,
#                     "y": 3447
#                 },
#                 "currentGold": 595,
#                 "totalGold": 3085,
#                 "level": 6,
#                 "xp": 2480,
#                 "minionsKilled": 1,
#                 "jungleMinionsKilled": 44
#             }
#         },
#         {
#             "2": {
#                 "participantId": 2,
#                 "position": {
#                     "x": 3309,
#                     "y": 12976
#                 },
#                 "currentGold": 1161,
#                 "totalGold": 1661,
#                 "level": 7,
#                 "xp": 3578,
#                 "minionsKilled": 22,
#                 "jungleMinionsKilled": 0
#             }
#         },
#         {
#             "3": {
#                 "participantId": 3,
#                 "position": {
#                     "x": 8247,
#                     "y": 8044
#                 },
#                 "currentGold": 1187,
#                 "totalGold": 3307,
#                 "level": 7,
#                 "xp": 3369,
#                 "minionsKilled": 38,
#                 "jungleMinionsKilled": 0
#             }
#         },
#         {
#             "4": {
#                 "participantId": 4,
#                 "position": {
#                     "x": 12297,
#                     "y": 2553
#                 },
#                 "currentGold": 688,
#                 "totalGold": 2488,
#                 "level": 5,
#                 "xp": 2209,
#                 "minionsKilled": 30,
#                 "jungleMinionsKilled": 0
#             }
#         },
#         {
#             "5": {
#                 "participantId": 5,
#                 "position": {
#                     "x": 11850,
#                     "y": 3312
#                 },
#                 "currentGold": 557,
#                 "totalGold": 2482,
#                 "level": 5,
#                 "xp": 2079,
#                 "minionsKilled": 7,
#                 "jungleMinionsKilled": 0
#             }
#         },
#         {
#             "6": {
#                 "participantId": 6,
#                 "position": {
#                     "x": 10190,
#                     "y": 5907
#                 },
#                 "currentGold": 962,
#                 "totalGold": 1812,
#                 "level": 5,
#                 "xp": 1734,
#                 "minionsKilled": 0,
#                 "jungleMinionsKilled": 24
#             }
#         },
#         {
#             "7": {
#                 "participantId": 7,
#                 "position": {
#                     "x": 7095,
#                     "y": 7905
#                 },
#                 "currentGold": 209,
#                 "totalGold": 1954,
#                 "level": 6,
#                 "xp": 2580,
#                 "minionsKilled": 34,
#                 "jungleMinionsKilled": 0
#             }
#         },
#         {
#             "8": {
#                 "participantId": 8,
#                 "position": {
#                     "x": 13955,
#                     "y": 4123
#                 },
#                 "currentGold": 1268,
#                 "totalGold": 2118,
#                 "level": 5,
#                 "xp": 2179,
#                 "minionsKilled": 42,
#                 "jungleMinionsKilled": 0
#             }
#         },
#         {
#             "9": {
#                 "participantId": 9,
#                 "position": {
#                     "x": 3442,
#                     "y": 13453
#                 },
#                 "currentGold": 2000,
#                 "totalGold": 2500,
#                 "level": 7,
#                 "xp": 3743,
#                 "minionsKilled": 60,
#                 "jungleMinionsKilled": 0
#             }
#         },
#         {
#             "10": {
#                 "participantId": 10,
#                 "position": {
#                     "x": 13210,
#                     "y": 3391
#                 },
#                 "currentGold": 163,
#                 "totalGold": 1513,
#                 "level": 4,
#                 "xp": 1674,
#                 "minionsKilled": 11,
#                 "jungleMinionsKilled": 0
#             }
#         }
#     ],
#     "540165": [
#         {
#             "1": {
#                 "participantId": 1,
#                 "position": {
#                     "x": 3453,
#                     "y": 8584
#                 },
#                 "currentGold": 1037,
#                 "totalGold": 3527,
#                 "level": 6,
#                 "xp": 2832,
#                 "minionsKilled": 1,
#                 "jungleMinionsKilled": 48
#             }
#         },
#         {
#             "2": {
#                 "participantId": 2,
#                 "position": {
#                     "x": 2626,
#                     "y": 12471
#                 },
#                 "currentGold": 1419,
#                 "totalGold": 1919,
#                 "level": 8,
#                 "xp": 4212,
#                 "minionsKilled": 26,
#                 "jungleMinionsKilled": 0
#             }
#         },
#         {
#             "3": {
#                 "participantId": 3,
#                 "position": {
#                     "x": 5359,
#                     "y": 5328
#                 },
#                 "currentGold": 649,
#                 "totalGold": 3644,
#                 "level": 7,
#                 "xp": 3677,
#                 "minionsKilled": 44,
#                 "jungleMinionsKilled": 0
#             }
#         },
#         {
#             "4": {
#                 "participantId": 4,
#                 "position": {
#                     "x": 13344,
#                     "y": 4080
#                 },
#                 "currentGold": 980,
#                 "totalGold": 2780,
#                 "level": 6,
#                 "xp": 2605,
#                 "minionsKilled": 37,
#                 "jungleMinionsKilled": 0
#             }
#         },
#         {
#             "5": {
#                 "participantId": 5,
#                 "position": {
#                     "x": 13328,
#                     "y": 3869
#                 },
#                 "currentGold": 778,
#                 "totalGold": 2703,
#                 "level": 6,
#                 "xp": 2474,
#                 "minionsKilled": 7,
#                 "jungleMinionsKilled": 0
#             }
#         },
#         {
#             "6": {
#                 "participantId": 6,
#                 "position": {
#                     "x": 3634,
#                     "y": 11491
#                 },
#                 "currentGold": 210,
#                 "totalGold": 1935,
#                 "level": 5,
#                 "xp": 1854,
#                 "minionsKilled": 0,
#                 "jungleMinionsKilled": 24
#             }
#         },
#         {
#             "7": {
#                 "participantId": 7,
#                 "position": {
#                     "x": 3553,
#                     "y": 11596
#                 },
#                 "currentGold": 92,
#                 "totalGold": 2077,
#                 "level": 6,
#                 "xp": 2580,
#                 "minionsKilled": 34,
#                 "jungleMinionsKilled": 0
#             }
#         },
#         {
#             "8": {
#                 "participantId": 8,
#                 "position": {
#                     "x": 14120,
#                     "y": 5061
#                 },
#                 "currentGold": 1538,
#                 "totalGold": 2388,
#                 "level": 6,
#                 "xp": 2441,
#                 "minionsKilled": 51,
#                 "jungleMinionsKilled": 0
#             }
#         },
#         {
#             "9": {
#                 "participantId": 9,
#                 "position": {
#                     "x": 3451,
#                     "y": 12954
#                 },
#                 "currentGold": 2277,
#                 "totalGold": 2777,
#                 "level": 8,
#                 "xp": 4223,
#                 "minionsKilled": 69,
#                 "jungleMinionsKilled": 0
#             }
#         },
#         {
#             "10": {
#                 "participantId": 10,
#                 "position": {
#                     "x": 13357,
#                     "y": 5128
#                 },
#                 "currentGold": 354,
#                 "totalGold": 1704,
#                 "level": 5,
#                 "xp": 1936,
#                 "minionsKilled": 14,
#                 "jungleMinionsKilled": 0
#             }
#         }
#     ],
#     "600171": [
#         {
#             "1": {
#                 "participantId": 1,
#                 "position": {
#                     "x": 7082,
#                     "y": 9655
#                 },
#                 "currentGold": 1395,
#                 "totalGold": 3885,
#                 "level": 7,
#                 "xp": 3341,
#                 "minionsKilled": 1,
#                 "jungleMinionsKilled": 58
#             }
#         },
#         {
#             "2": {
#                 "participantId": 2,
#                 "position": {
#                     "x": 1486,
#                     "y": 11015
#                 },
#                 "currentGold": 1562,
#                 "totalGold": 2062,
#                 "level": 8,
#                 "xp": 4333,
#                 "minionsKilled": 27,
#                 "jungleMinionsKilled": 0
#             }
#         },
#         {
#             "3": {
#                 "participantId": 3,
#                 "position": {
#                     "x": 7564,
#                     "y": 8185
#                 },
#                 "currentGold": 960,
#                 "totalGold": 3955,
#                 "level": 8,
#                 "xp": 4338,
#                 "minionsKilled": 55,
#                 "jungleMinionsKilled": 0
#             }
#         },
#         {
#             "4": {
#                 "participantId": 4,
#                 "position": {
#                     "x": 11477,
#                     "y": 1594
#                 },
#                 "currentGold": 213,
#                 "totalGold": 2938,
#                 "level": 6,
#                 "xp": 2725,
#                 "minionsKilled": 39,
#                 "jungleMinionsKilled": 0
#             }
#         },
#         {
#             "5": {
#                 "participantId": 5,
#                 "position": {
#                     "x": 8715,
#                     "y": 1117
#                 },
#                 "currentGold": 503,
#                 "totalGold": 2903,
#                 "level": 6,
#                 "xp": 2474,
#                 "minionsKilled": 7,
#                 "jungleMinionsKilled": 0
#             }
#         },
#         {
#             "6": {
#                 "participantId": 6,
#                 "position": {
#                     "x": 7505,
#                     "y": 9836
#                 },
#                 "currentGold": 395,
#                 "totalGold": 2120,
#                 "level": 5,
#                 "xp": 2275,
#                 "minionsKilled": 4,
#                 "jungleMinionsKilled": 24
#             }
#         },
#         {
#             "7": {
#                 "participantId": 7,
#                 "position": {
#                     "x": 9808,
#                     "y": 9613
#                 },
#                 "currentGold": 214,
#                 "totalGold": 2199,
#                 "level": 6,
#                 "xp": 2636,
#                 "minionsKilled": 34,
#                 "jungleMinionsKilled": 0
#             }
#         },
#         {
#             "8": {
#                 "participantId": 8,
#                 "position": {
#                     "x": 12305,
#                     "y": 5189
#                 },
#                 "currentGold": 302,
#                 "totalGold": 2552,
#                 "level": 6,
#                 "xp": 2630,
#                 "minionsKilled": 54,
#                 "jungleMinionsKilled": 0
#             }
#         },
#         {
#             "9": {
#                 "participantId": 9,
#                 "position": {
#                     "x": 1902,
#                     "y": 12759
#                 },
#                 "currentGold": 2625,
#                 "totalGold": 3125,
#                 "level": 8,
#                 "xp": 4974,
#                 "minionsKilled": 79,
#                 "jungleMinionsKilled": 0
#             }
#         },
#         {
#             "10": {
#                 "participantId": 10,
#                 "position": {
#                     "x": 13148,
#                     "y": 3154
#                 },
#                 "currentGold": 579,
#                 "totalGold": 1929,
#                 "level": 6,
#                 "xp": 2577,
#                 "minionsKilled": 19,
#                 "jungleMinionsKilled": 0
#             }
#         }
#     ],
#     "660185": [
#         {
#             "1": {
#                 "participantId": 1,
#                 "position": {
#                     "x": 4591,
#                     "y": 9828
#                 },
#                 "currentGold": 1710,
#                 "totalGold": 4200,
#                 "level": 7,
#                 "xp": 3660,
#                 "minionsKilled": 1,
#                 "jungleMinionsKilled": 62
#             }
#         },
#         {
#             "2": {
#                 "participantId": 2,
#                 "position": {
#                     "x": 1319,
#                     "y": 9860
#                 },
#                 "currentGold": 298,
#                 "totalGold": 2248,
#                 "level": 8,
#                 "xp": 4693,
#                 "minionsKilled": 31,
#                 "jungleMinionsKilled": 0
#             }
#         },
#         {
#             "3": {
#                 "participantId": 3,
#                 "position": {
#                     "x": 7379,
#                     "y": 7199
#                 },
#                 "currentGold": 1627,
#                 "totalGold": 4632,
#                 "level": 9,
#                 "xp": 5154,
#                 "minionsKilled": 61,
#                 "jungleMinionsKilled": 0
#             }
#         },
#         {
#             "4": {
#                 "participantId": 4,
#                 "position": {
#                     "x": 13063,
#                     "y": 2598
#                 },
#                 "currentGold": 520,
#                 "totalGold": 3245,
#                 "level": 7,
#                 "xp": 3266,
#                 "minionsKilled": 51,
#                 "jungleMinionsKilled": 0
#             }
#         },
#         {
#             "5": {
#                 "participantId": 5,
#                 "position": {
#                     "x": 13585,
#                     "y": 2732
#                 },
#                 "currentGold": 697,
#                 "totalGold": 3097,
#                 "level": 6,
#                 "xp": 2925,
#                 "minionsKilled": 8,
#                 "jungleMinionsKilled": 0
#             }
#         },
#         {
#             "6": {
#                 "participantId": 6,
#                 "position": {
#                     "x": 8702,
#                     "y": 8491
#                 },
#                 "currentGold": 281,
#                 "totalGold": 2306,
#                 "level": 6,
#                 "xp": 2646,
#                 "minionsKilled": 8,
#                 "jungleMinionsKilled": 24
#             }
#         },
#         {
#             "7": {
#                 "participantId": 7,
#                 "position": {
#                     "x": 13885,
#                     "y": 13577
#                 },
#                 "currentGold": 90,
#                 "totalGold": 2375,
#                 "level": 6,
#                 "xp": 2925,
#                 "minionsKilled": 35,
#                 "jungleMinionsKilled": 1
#             }
#         },
#         {
#             "8": {
#                 "participantId": 8,
#                 "position": {
#                     "x": 13848,
#                     "y": 4211
#                 },
#                 "currentGold": 619,
#                 "totalGold": 2869,
#                 "level": 6,
#                 "xp": 3007,
#                 "minionsKilled": 62,
#                 "jungleMinionsKilled": 0
#             }
#         },
#         {
#             "9": {
#                 "participantId": 9,
# ...
#                     "x": 1126,
#                     "y": 10654
#                 },
#                 "currentGold": 886,
#                 "totalGold": 4211,
#                 "level": 9,
#                 "xp": 6068,
#                 "minionsKilled": 94,
#                 "jungleMinionsKilled": 0
#             }
#         },
#         {
#             "10": {
#                 "participantId": 10,
#                 "position": {
#                     "x": 13461,
#                     "y": 3949
#                 },
#                 "currentGold": 237,
#                 "totalGold": 2437,
#                 "level": 7,
#                 "xp": 3530,
#                 "minionsKilled": 26,
#                 "jungleMinionsKilled": 0
#             }
#         }
#     ],
#     "840238": [
#         {
#             "1": {
#                 "participantId": 1,
#                 "position": {
#                     "x": 13126,
#                     "y": 5380
#                 },
#                 "currentGold": 3315,
#                 "totalGold": 5805,
#                 "level": 9,
#                 "xp": 5486,
#                 "minionsKilled": 11,
#                 "jungleMinionsKilled": 74
#             }
#         },
#         {
#             "2": {
#                 "participantId": 2,
#                 "position": {
#                     "x": 1904,
#                     "y": 11964
#                 },
#                 "currentGold": 558,
#                 "totalGold": 3258,
#                 "level": 9,
#                 "xp": 6100,
#                 "minionsKilled": 41,
#                 "jungleMinionsKilled": 0
#             }
#         },
#         {
#             "3": {
#                 "participantId": 3,
#                 "position": {
#                     "x": 2134,
#                     "y": 1213
#                 },
#                 "currentGold": 160,
#                 "totalGold": 6950,
#                 "level": 10,
#                 "xp": 6826,
#                 "minionsKilled": 75,
#                 "jungleMinionsKilled": 4
#             }
#         },
#         {
#             "4": {
#                 "participantId": 4,
#                 "position": {
#                     "x": 13127,
#                     "y": 3415
#                 },
#                 "currentGold": 1902,
#                 "totalGold": 4627,
#                 "level": 8,
#                 "xp": 4593,
#                 "minionsKilled": 62,
#                 "jungleMinionsKilled": 0
#             }
#         },
#         {
#             "5": {
#                 "participantId": 5,
#                 "position": {
#                     "x": 13094,
#                     "y": 5049
#                 },
#                 "currentGold": 2925,
#                 "totalGold": 5325,
#                 "level": 8,
#                 "xp": 4549,
#                 "minionsKilled": 14,
#                 "jungleMinionsKilled": 0
#             }
#         },
#         {
#             "6": {
#                 "participantId": 6,
#                 "position": {
#                     "x": 13466,
#                     "y": 6473
#                 },
#                 "currentGold": 84,
#                 "totalGold": 2934,
#                 "level": 7,
#                 "xp": 3987,
#                 "minionsKilled": 13,
#                 "jungleMinionsKilled": 24
#             }
#         },
#         {
#             "7": {
#                 "participantId": 7,
#                 "position": {
#                     "x": 11809,
#                     "y": 11538
#                 },
#                 "currentGold": 202,
#                 "totalGold": 3097,
#                 "level": 7,
#                 "xp": 3861,
#                 "minionsKilled": 47,
#                 "jungleMinionsKilled": 1
#             }
#         },
#         {
#             "8": {
#                 "participantId": 8,
#                 "position": {
#                     "x": 14121,
#                     "y": 4642
#                 },
#                 "currentGold": 849,
#                 "totalGold": 3699,
#                 "level": 7,
#                 "xp": 3916,
#                 "minionsKilled": 80,
#                 "jungleMinionsKilled": 0
#             }
#         },
#         {
#             "9": {
#                 "participantId": 9,
#                 "position": {
#                     "x": 3295,
#                     "y": 10944
#                 },
#                 "currentGold": 1362,
#                 "totalGold": 4687,
#                 "level": 10,
#                 "xp": 6492,
#                 "minionsKilled": 101,
#                 "jungleMinionsKilled": 0
#             }
#         },
#         {
#             "10": {
#                 "participantId": 10,
#                 "position": {
#                     "x": 13956,
#                     "y": 8445
#                 },
#                 "currentGold": 322,
#                 "totalGold": 3472,
#                 "level": 7,
#                 "xp": 3870,
#                 "minionsKilled": 26,
#                 "jungleMinionsKilled": 0
#             }
#         }
#     ],
#     "900248": [
#         {
#             "1": {
#                 "participantId": 1,
#                 "position": {
#                     "x": 3513,
#                     "y": 8890
#                 },
#                 "currentGold": 147,
#                 "totalGold": 6012,
#                 "level": 9,
#                 "xp": 5577,
#                 "minionsKilled": 11,
#                 "jungleMinionsKilled": 74
#             }
#         },
#         {
#             "2": {
#                 "participantId": 2,
#                 "position": {
#                     "x": 1438,
#                     "y": 10872
#                 },
#                 "currentGold": 758,
#                 "totalGold": 3458,
#                 "level": 10,
#                 "xp": 6522,
#                 "minionsKilled": 43,
#                 "jungleMinionsKilled": 0
#             }
#         },
#         {
#             "3": {
#                 "participantId": 3,
#                 "position": {
#                     "x": 7053,
#                     "y": 10275
#                 },
#                 "currentGold": 713,
#                 "totalGold": 7503,
#                 "level": 11,
#                 "xp": 7550,
#                 "minionsKilled": 81,
#                 "jungleMinionsKilled": 8
#             }
#         },
#         {
#             "4": {
#                 "participantId": 4,
#                 "position": {
#                     "x": 4416,
#                     "y": 852
#                 },
#                 "currentGold": 167,
#                 "totalGold": 5217,
#                 "level": 8,
#                 "xp": 4768,
#                 "minionsKilled": 64,
#                 "jungleMinionsKilled": 0
#             }
#         },
#         {
#             "5": {
#                 "participantId": 5,
#                 "position": {
#                     "x": 5484,
#                     "y": 868
#                 },
#                 "currentGold": 50,
#                 "totalGold": 5550,
#                 "level": 8,
#                 "xp": 4723,
#                 "minionsKilled": 14,
#                 "jungleMinionsKilled": 0
#             }
#         },
#         {
#             "6": {
#                 "participantId": 6,
#                 "position": {
#                     "x": 8138,
#                     "y": 9958
#                 },
#                 "currentGold": 206,
#                 "totalGold": 3056,
#                 "level": 7,
#                 "xp": 4047,
#                 "minionsKilled": 13,
#                 "jungleMinionsKilled": 24
#             }
#         },
#         {
#             "7": {
#                 "participantId": 7,
#                 "position": {
#                     "x": 8771,
#                     "y": 9748
#                 },
#                 "currentGold": 674,
#                 "totalGold": 3569,
#                 "level": 8,
#                 "xp": 4675,
#                 "minionsKilled": 64,
#                 "jungleMinionsKilled": 1
#             }
#         },
#         {
#             "8": {
#                 "participantId": 8,
#                 "position": {
#                     "x": 12622,
#                     "y": 2958
#                 },
#                 "currentGold": 455,
#                 "totalGold": 3905,
#                 "level": 8,
#                 "xp": 4171,
#                 "minionsKilled": 85,
#                 "jungleMinionsKilled": 0
#             }
#         },
#         {
#             "9": {
#                 "participantId": 9,
#                 "position": {
#                     "x": 3308,
#                     "y": 11007
#                 },
#                 "currentGold": 1673,
#                 "totalGold": 4998,
#                 "level": 10,
#                 "xp": 7155,
#                 "minionsKilled": 108,
#                 "jungleMinionsKilled": 0
#             }
#         },
#         {
#             "10": {
#                 "participantId": 10,
#                 "position": {
#                     "x": 12122,
#                     "y": 3374
#                 },
#                 "currentGold": 533,
#                 "totalGold": 3683,
#                 "level": 8,
#                 "xp": 4367,
#                 "minionsKilled": 31,
#                 "jungleMinionsKilled": 0
#             }
#         }
#     ],
#     "960281": [
#         {
#             "1": {
#                 "participantId": 1,
#                 "position": {
#                     "x": 6568,
#                     "y": 12586
#                 },
#                 "currentGold": 474,
#                 "totalGold": 6339,
#                 "level": 10,
#                 "xp": 6221,
#                 "minionsKilled": 12,
#                 "jungleMinionsKilled": 74
#             }
#         },
#         {
#             "2": {
#                 "participantId": 2,
#                 "position": {
#                     "x": 7201,
#                     "y": 13420
#                 },
#                 "currentGold": 1042,
#                 "totalGold": 3742,
#                 "level": 10,
#                 "xp": 7139,
#                 "minionsKilled": 45,
#                 "jungleMinionsKilled": 0
#             }
#         },
#         {
#             "3": {
#                 "participantId": 3,
#                 "position": {
#                     "x": 7229,
#                     "y": 13532
#                 },
#                 "currentGold": 1808,
#                 "totalGold": 8598,
#                 "level": 11,
#                 "xp": 8453,
#                 "minionsKilled": 97,
#                 "jungleMinionsKilled": 12
#             }
#         },
#         {
#             "4": {
#                 "participantId": 4,
#                 "position": {
#                     "x": 11771,
#                     "y": 1540
#                 },
#                 "currentGold": 808,
#                 "totalGold": 5858,
#                 "level": 9,
#                 "xp": 5439,
#                 "minionsKilled": 74,
#                 "jungleMinionsKilled": 0
#             }
#         },
#         {
#             "5": {
#                 "participantId": 5,
#                 "position": {
#                     "x": 12266,
#                     "y": 1728
#                 },
#                 "currentGold": 435,
#                 "totalGold": 5935,
#                 "level": 9,
#                 "xp": 5343,
#                 "minionsKilled": 16,
#                 "jungleMinionsKilled": 0
#             }
#         },
#         {
#             "6": {
#                 "participantId": 6,
#                 "position": {
#                     "x": 8175,
#                     "y": 13483
#                 },
#                 "currentGold": 329,
#                 "totalGold": 3179,
#                 "level": 7,
#                 "xp": 4047,
#                 "minionsKilled": 13,
#                 "jungleMinionsKilled": 24
#             }
#         },
#         {
#             "7": {
#                 "participantId": 7,
#                 "position": {
#                     "x": 9205,
#                     "y": 9693
#                 },
#                 "currentGold": 301,
#                 "totalGold": 3821,
#                 "level": 8,
#                 "xp": 4917,
#                 "minionsKilled": 68,
#                 "jungleMinionsKilled": 1
#             }
#         },
#         {
#             "8": {
#                 "participantId": 8,
#                 "position": {
#                     "x": 12929,
#                     "y": 1810
#                 },
#                 "currentGold": 805,
#                 "totalGold": 4255,
#                 "level": 8,
#                 "xp": 4567,
#                 "minionsKilled": 94,
#                 "jungleMinionsKilled": 0
#             }
#         },
#         {
#             "9": {
#                 "participantId": 9,
#                 "position": {
#                     "x": 4562,
#                     "y": 13873
#                 },
#                 "currentGold": 1817,
#                 "totalGold": 5142,
#                 "level": 10,
#                 "xp": 7276,
#                 "minionsKilled": 109,
#                 "jungleMinionsKilled": 0
#             }
#         },
#         {
#             "10": {
#                 "participantId": 10,
#                 "position": {
#                     "x": 12216,
#                     "y": 2387
#                 },
#                 "currentGold": 709,
#                 "totalGold": 3859,
#                 "level": 8,
#                 "xp": 4763,
#                 "minionsKilled": 33,
#                 "jungleMinionsKilled": 0
#             }
#         }
#     ],
#     "1020281": [
#         {
#             "1": {
#                 "participantId": 1,
#                 "currentGold": 469,
#                 "totalGold": 6394,
#                 "level": 10,
#                 "xp": 6308,
#                 "minionsKilled": 12,
#                 "jungleMinionsKilled": 75
#             }
#         },
#         {
#             "2": {
#                 "participantId": 2,
#                 "currentGold": 1065,
#                 "totalGold": 3765,
#                 "level": 10,
#                 "xp": 7139,
#                 "minionsKilled": 45,
#                 "jungleMinionsKilled": 0
#             }
#         },
#         {
#             "3": {
#                 "participantId": 3,
#                 "currentGold": 1871,
#                 "totalGold": 8621,
#                 "level": 11,
#                 "xp": 8453,
#                 "minionsKilled": 97,
#                 "jungleMinionsKilled": 12
#             }
#         },
#         {
#             "4": {
#                 "participantId": 4,
#                 "currentGold": 1120,
#                 "totalGold": 6170,
#                 "level": 9,
#                 "xp": 5720,
#                 "minionsKilled": 75,
#                 "jungleMinionsKilled": 0
#             }
#         },
#         {
#             "5": {
#                 "participantId": 5,
#                 "currentGold": 599,
#                 "totalGold": 6099,
#                 "level": 9,
#                 "xp": 5624,
#                 "minionsKilled": 16,
#                 "jungleMinionsKilled": 0
#             }
#         },
#         {
#             "6": {
#                 "participantId": 6,
#                 "currentGold": 352,
#                 "totalGold": 3202,
#                 "level": 7,
#                 "xp": 4047,
#                 "minionsKilled": 13,
#                 "jungleMinionsKilled": 24
#             }
#         },
#         {
#             "7": {
#                 "participantId": 7,
#                 "currentGold": -6,
#                 "totalGold": 3844,
#                 "level": 8,
#                 "xp": 4917,
#                 "minionsKilled": 68,
#                 "jungleMinionsKilled": 1
#             }
#         },
#         {
#             "8": {
#                 "participantId": 8,
#                 "currentGold": 828,
#                 "totalGold": 4278,
#                 "level": 8,
#                 "xp": 4567,
#                 "minionsKilled": 94,
#                 "jungleMinionsKilled": 0
#             }
#         },
#         {
#             "9": {
#                 "participantId": 9,
#                 "currentGold": 40,
#                 "totalGold": 5165,
#                 "level": 10,
#                 "xp": 7276,
#                 "minionsKilled": 109,
#                 "jungleMinionsKilled": 0
#             }
#         },
#         {
#             "10": {
#                 "participantId": 10,
#                 "currentGold": 736,
#                 "totalGold": 3886,
#                 "level": 8,
#                 "xp": 4763,
#                 "minionsKilled": 33,
#                 "jungleMinionsKilled": 0
#             }
#         }
#     ]
# }

# %%
testing = {'a':1, 'b':2, 'c':3}
dir(testing)
# Out:
# ['__class__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'clear',
#  'copy',
#  'fromkeys',
#  'get',
#  'items',
#  'keys',
#  'pop',
#  'popitem',
#  'setdefault',
#  'update',
#  'values']

# %%
testing.items()
# Out:
# dict_items([('a', 1), ('b', 2), ('c', 3)])

# %%
dir(testing.items())
# Out:
# ['__and__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__rand__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__ror__',
#  '__rsub__',
#  '__rxor__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__xor__',
#  'isdisjoint']

# %%
# Out:
# <class 'dict_items'>
